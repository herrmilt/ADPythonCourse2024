# %% [markdown]
# # Dictionaries and Sets
# <a id='sec_dicts_and_sets'></a>
#
# Let's start by understanding what dictionaries are in Python. A dictionary is a data structure that
# stores key-value pairs. We can create a dictionary in Python using curly braces {}. For example:

# %%
my_dictionary = {'name': 'John', 'age': 28, 'profession': 'programmer'}
my_dictionary
# Out:
# {'name': 'John', 'age': 28, 'profession': 'programmer'}

# %% [markdown]
# Keys and values can be of different data types

# %%
a_dict = {2: "two", False: 23, "values": [3, 4, 5]}
a_dict
# Out:
# {2: 'two', False: 23, 'values': [3, 4, 5]}

# %% [markdown]
# Keys must be inmutable

# %%
{(2, 3): True, "text": False}
# Out:
# {(2, 3): True, 'text': False}

# %%
{[3, 4, 5]: 45}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 {[3, 4, 5]: 45}
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# We can access the values of the dictionary using the corresponding key. For example:

# %%
my_dictionary
# Out:
# {'name': 'John', 'age': 28, 'profession': 'programmer'}

# %%
my_dictionary['name']
# Out:
# 'John'

# %% [markdown]
# If an element is not in the dictionary, a KeyError exception is thrown

# %%
cucu = {2: None}
print(cucu[2])
# Out:
# None

# %%
my_dictionary['gender']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 my_dictionary['gender']
#
# KeyError: 'gender'

# %% [markdown]
# We can add a new key-value pair to the dictionary:

# %%
my_dictionary['location'] = 'New York'
my_dictionary
# Out:
# {'name': 'John', 'age': 28, 'profession': 'programmer', 'location': 'New York'}

# %% [markdown]
# We can also update an existing value:

# %%
my_dictionary['age']
# Out:
# 28

# %%
my_dictionary['age'] = 50
my_dictionary
# Out:
# {'name': 'John', 'age': 50, 'profession': 'programmer', 'location': 'New York'}

# %% [markdown]
# And we can delete a key-value pair using the del keyword:

# %%
del my_dictionary['age']
my_dictionary
# Out:
# {'name': 'John', 'profession': 'programmer', 'location': 'New York'}

# %% [markdown]
# Checking if a key exists in a dictionary:

# %%
my_dict = {'name': 'John', 'age': 30, 'city': 'New York'}
'name' in my_dict
# Out:
# True

# %%
30 in my_dict
# Out:
# False

# %% [markdown]
# Getting all keys or values from a dictionary:

# %%
print(my_dict.keys())
print(my_dict.values())
# Out:
# dict_keys(['name', 'age', 'city'])
# dict_values(['John', 30, 'New York'])

# %% [markdown]
# Looping through the key, value pairs in a dictionary

# %%
for key, value in my_dict.items():
    print(key, value)
# Out:
# name John
# age 30
# city New York

# %% [markdown]
# Clearing the dictionary

# %%
my_dict = {'name': 'John', 'age': 30, 'city': 'New York'}
my_dict.clear()
my_dict
# Out:
# {}

# %% [markdown]
# The get() method is used to retrieve the value for a given key from a dictionary. It takes two arguments - the key and a default value to return if the key is not found in the dictionary.
#
# If the key is found, the corresponding value is returned. Otherwise, the default
# value is returned.

# %%
my_dict = {'name': 'John', 'age': 30, 'city': 'New York'}
print(my_dict.get('name', 23))
print(my_dict.get('gender', 14))
# Out:
# John
# 14

# %%
if 'namex' in my_dict:
    print(my_dict['name'])

# %%
name = my_dict.get('namex', None)
if not(name is None):
    print(name)

# %% [markdown]
# ### Sets
#
# A set is an unordered collection of unique elements. It is a built-in data type that provides a convenient way to store and manipulate distinct values

# %%
a = {1: [2, 3, 4], 2: 'lolo'}
b = a[1]

# %%
b.append(12)

# %%
a
# Out:
# {1: [2, 3, 4, 12], 2: 'lolo'}

# %%
my_set = {1, 2, 3}
my_set
# Out:
# {1, 2, 3}

# %% [markdown]
# Sets only contain unique elements. If duplicate values are specified during set creation, they are automatically eliminated, leaving only unique values in the set

# %%
my_set = {1, 2, 2, 3, 3, 3}
my_set
# Out:
# {1, 2, 3}

# %%
lolo = {}

# %% [markdown]
# Sets support various operations such as union, intersection, difference, and more. These operations can be performed using built-in methods or operators

# %%
set1 = {1, 2, 3}
set2 = {2, 3, 4}
set1.union(set2)
# Out:
# {1, 2, 3, 4}

# %%
set1.intersection(set2)
# Out:
# {2, 3}

# %%
set1.difference(set2)
# Out:
# {1}

# %% [markdown]
# Sets are mutable, which means you can add or remove elements from a set after its creation

# %%
my_set = {1, 2, 3}
my_set.add(4)      # Add a single element
my_set.update({5, 6})  # Add multiple elements
my_set.remove(2)   # Remove an element
my_set
# Out:
# {1, 3, 4, 5, 6}

# %% [markdown]
# You can check if an element is present in a set using the in operator

# %%
my_set = {1, 2, 3}
print(2 in my_set)  
print(4 in my_set)
# Out:
# True
# False

# %% [markdown]
# ## Solved Exercises

# %% [markdown]
# **Exercise**. Create a dictionary representing a student's information (name, age, grade) and print each key-value pair.

# %%
student = {
    "name": "John Smith",
    "age": 17,
    "grade": "11th"
}

for key, value in student.items():
    print(key, ":", value)

# %% [markdown]
# **Exercise**. Given a list of names, create a dictionary where the names are the keys and the values represent their lengths.

# %%
names = ["Alice", "Bob", "Charlie", "David"]

name_lengths = {}
for name in names:
    name_lengths[name] = len(name)

name_lengths

# %% [markdown]
# **Exercise**. Count the frequency of each character in a given string and store it in a dictionary.

# %%
string = "hello world"

char_frequency = {}
for char in string:
    if char in char_frequency:
        char_frequency[char] += 1
    else:
        char_frequency[char] = 1

char_frequency

# %%
string = "hello world"

char_frequency = {}
for char in string:
    char_frequency[char] = char_frequency.get(char, 0) + 1

char_frequency

# %% [markdown]
# **Exercise**. Create a dictionary that maps grades to corresponding grade points (A: 4, B: 3, C: 2, D: 1, F: 0). Given a list of grades, calculate the GPA (Grade Point Average).

# %%
grades = ["A", "B", "C", "A", "B"]

grade_points = {
    "A": 4,
    "B": 3,
    "C": 2,
    "D": 1,
    "F": 0
}

total_points = sum(grade_points[grade] for grade in grades)
gpa = total_points / len(grades)

print("GPA:", gpa)

# %% [markdown]
# **Exercise**. Create a dictionary of fruit prices per pound.
# Enter the name of the fruit and the quantity, print the total price

# %%
fruits = {"mango": 2.3, "strawberry": 3.5, "melon": 2.4}
name = input("Enter fruit:")
quantity = float(input("Enter quantity:"))
price = fruits.get(name, None)
if price is not None:
    print("Total price:", price * quantity)
else:
    print("Unregistered fruit:", name)

# %% [markdown]
# **Exercise**. Enter the amount of RMB from a person and the currency to convert.
# Print the converted amount.
# The exchange rate for each currency and its symbol (for the result) should be stored in a dictionary.

# %%
rates = {
    "eur": {"rate": 8.2, "symbol": "€"},
    "cup": {"rate": 0.3, "symbol": "₱"},
    "usd": {"rate": 7.6, "symbol": "$"}
}

rmb = float(input("Enter RMB amount:"))
currency = input("Enter destination currency (eur, cup, usd):")
rate = rates.get(currency.lower(), None)
if rate is not None:
    converted = rmb / rate['rate']
    print("The result is", converted, rate['symbol'])
else:
    print("Invalid currency:", currency)

# %% [markdown]
# **Exercise**. Write a program that creates an empty dictionary and gradually fills it with information about a person (such as name, age, gender, phone number, email, etc.) prompted from the user. The input format should be <name>=<value> (e.g., age=24). Each time a new data is added, the contents of the dictionary should be printed.

# %%
d = {}
finish = False
while not finish:
    info = input("Enter property (<name>=<value>)")
    if info == "":
        finish = True
        print("Finished")
    else:
        comps = info.split("=")
        if len(comps) != 2:
            print("Incorrect format, should be <name>=<value>")
        else:
            d[comps[0].strip()] = comps[1].strip()
            print(d)

# %% [markdown]
# The following lines load all the lines from an online dictionary

# %%
import re
with open("data/dict_EngEsp.txt", "r", encoding='iso-8859-1',
                 errors='ignore') as f:
    lines = [re.sub(r"\[.*\]|\(.*\)|/","",l) for l in f.readlines()]

# %%
lines
# Out:
# ['###########################################################################\n',
#  '#Copyright 1999 The Internet Dictionary ProjectTyler Chambers\n',
#  '#http:www.june29.comIDP\n',
#  '#This file is free to use and modify.  Thank you for using the IDP.\n',
#  '#\n',
#  '#Approximately 5048 entries.  92197\n',
#  '#Approximately 5488 entries.  1798\n',
#  '#Approximately 5910 entries.  3898\n',
#  '#Approximately 7450 entries.  21999\n',
#  '###########################################################################\n',
#  'a\tun, uno, una\n',
#  'aardvark\tcerdo hormiguero\n',
#  'aardvark\toso hormiguero\n',
#  'aardvarks\tcerdos hormigueros\n',
#  'aardvarks\tosos hormigueros \n',
#  'ab\tprefijo que indica separacion\n',
#  'aback\thacia atras\n',
#  'aback\thacia atrás,take aback, desconcertar. En facha.\n',
#  'aback\tpor sopresa, desprevenidamente, de improviso\n',
#  'aback\tatras\n',
#  'abacterial\tabacteriano, sin bacterias\n',
#  'abacus\tabaco\n',
#  'abacuses\tabacos\n',
#  'abaft\tA popa \n',
#  'abaft\tdetras de\n',
#  'abalone\tabulon\n',
#  'abalone\toreja de mar \n',
#  'abalone\toreja de mar\n',
#  'abalones\tabulones\n',
#  'abalones\torejas de mar \n',
#  'abalones\torejas de mar\n',
#  'abandon\tabandonar\n',
#  'abandon\tdarse por vencido\n',
#  'abandon\tdejar\n',
#  'abandon\tdesamparar, desertar, renunciar, evacuar, repudiar\n',
#  'abandon\trenunciar a\n',
#  'abandon\tabandono\n',
#  'abandoned\tabandonado\n',
#  'abandoned\tdejado\n',
#  'abandoned\tdesamparado\n',
#  'abandoned\tolvidado\n',
#  'abandoned\tabandonada,abandonado, abandonados, abandonadas\n',
#  'abandonee\tabandonado\n',
#  'abandonee\taislado\n',
#  'abandonee\tdejado\n',
#  'abandonee\tdesamparado\n',
#  'abandonee\tmoney\n',
#  'abandoner\tabandonador\n',
#  'abandoning\tabandonando\n',
#  'abandoning\tabandono\n',
#  'abandonment\tabandono\n',
#  'abandonment\tdesamparo, deserción\n',
#  'abandonments\tabandonos\n',
#  'abandons\tabandona\n',
#  'abandons\tdesampara\n',
#  'abase\tabatir\n',
#  'abase\tabatir, envilecer\n',
#  'abase\tdenigrar\n',
#  'abase\trebajar, humillar, degradar\n',
#  'abase\trebajar, degradar, humillar, abatir\n',
#  'abased\tdegradado\n',
#  'abased\trebajado, humillado, degradado\n',
#  'abased\trebajado, degradado, humillado, abatido\n',
#  'abasement\tenvilecimiento\n',
#  'abasement\thumillacion, degradacion\n',
#  'abasement\trebajacion, degradacion, humillacion, abatimiento\n',
#  'abasements\thumillaciones, degradaciones\n',
#  'abaser\thumillador\n',
#  'abases\tdegrada; humilla\n',
#  'abash\tavergonzar\n',
#  'abash\tavergonzar, abochornar, confundir\n',
#  'abash\tavergonzar, confundir, \n',
#  'abashed\tavergonzado\n',
#  'abashes\tavergu.enza; pone en situacion embarazosa\n',
#  'abashing\tvergonzante, vergonzoso\n',
#  'abashing\tvergonzoso\n',
#  'abashment\tVergüenza.\n',
#  'abashment\tverguenza\n',
#  'abasing\thumillante\n',
#  'abasing\thumillante, degradante\n',
#  'abate\tamainar\n',
#  'abate\tdisminuir, reducir, mitigar\n',
#  'abate\tmitigar\n',
#  'abate\tterminar, hacer cesar\n',
#  'abated\tamainado, amplacado, mitigado\n',
#  'abated\taplacado, abolido, descontado, disminuido.NO AMPLACADO\n',
#  'abatement\tAbolición, supresión\n',
#  'abatement\tdescuento, rebaja\n',
#  'abatements\tRebajas, descuentos, decaimientos,aboliciones\n',
#  'abatements\ts. descuento, rebaja, decaimiento\n',
#  'abater\trebajador, mitigador\n',
#  'abates\tsatélites\n',
#  'abating\t superando una marca; disminuyendo; situacion depresiva\n',
#  'abating\tdeprimente, calmante, aboliendo, disminuyendo, amainando, rebajando. NO SUPERAR UNA MARCA, en castellano es batir una marca: break a record\n',
#  'abatis\tbarricada con alambre de púas, parapeto de troncos caídos\n',
#  'abatis\ttala, abatida, barricada de alambre de púas\n',
#  'abatises\tBarricads, parapetos, obstáculos\n',
#  'abatises\tsesame\n',
#  'abatises\tBarricadas\n',
#  'abattoir\tdegolladero, macelo, matadero.\n',
#  'abattoir\tmatadero de reses\n',
#  'abattoir\tmatadero \n',
#  'abaxial\tabacial\n',
#  'abaxial\textraaxial\n',
#  'abaxial\tNo situado en el eje, lejos del eje, desalineado. NO ES CORRECTO ABACIAL=ABBATIAL\n',
#  'abaxial\tabaxial,  aquella region de un organo alejada del eje\n',
#  'abbacy\tAbadía, convento, monasterio.\n',
#  'abbacy\tabadia\n',
#  'abbas\tABBA= Padre, Dios. ABBAS, tío de Mahoma.\n',
#  'abbas\taint\n',
#  'abbe\tabate\n',
#  'abbe\tABBÉ=Abate\n',
#  'abberations\tAberración\n',
#  'abberations\taberracion\n',
#  'abberations\tdesvio\n',
#  'abberations\tUNKNOWN WORD IN ENGLISH\n',
#  'abbey\tabadia\n',
#  'abbey\tabadía\n',
#  'abbeys\tAbadías, monasterios, conventos\n',
#  'abbeys\tabadias\n',
#  'abbot\tAbad\n',
#  'abbot\tabad\n',
#  'abbots\tabades\n',
#  'abbots\tAbates. NO ABADES.\n',
#  'abbreviate\tabreviar\n',
#  'abbreviate\tAbreviar, simplificar.\n',
#  'abbreviate\tacortar\n',
#  'abbreviate\tabreviar\n',
#  'abbreviated\tabreviado\n',
#  'abbreviated\tAbreviado, simplificado, acortado, reducido.NO CORTADO.\n',
#  'abbreviated\tcortado\n',
#  'abbreviates\tabrevia\n',
#  'abbreviates\tReducciones, resúmenes, abreviaciones, compendios.\n',
#  'abbreviating\tabreviando\n',
#  'abbreviation\tabreviacion\n',
#  'abbreviation\tabreviatura\n',
#  'abbreviation\tabreviatura\n',
#  'abbreviations\tabreviaciones\n',
#  'abbreviations\tabreviaturas\n',
#  'abbreviator\tabreviador\n',
#  'abc\tabc\n',
#  'abc\tabecedario\n',
#  'abdicable\tabdicable, que puede abdicar\n',
#  'abdicate\tabdicar\n',
#  'abdicate\trenunciar a; abdicar\n',
#  'abdicated\tabdicado \n',
#  'abdication\tabdicacion\n',
#  'abdication\trenuncia; abdicación \n',
#  'abdicator\tabdicador\n',
#  'abdomen\tabdomen\n',
#  'abdomen\tabdomen\n',
#  'abdomen\tbarriga, vientre\n',
#  'abdomens\tabdomenes\n',
#  'abdomens\tabdomenes\n',
#  'abdomens\tabdómenes\n',
#  'abdominal\tabdominal\n',
#  'abdominally\tabdominalmente\n',
#  'abduce\tabducir\n',
#  'abduced\tabducido\n',
#  'abducens\tmúsculo abductor\n',
#  'abducens\tseparador\n',
#  'abducent\tAbductor\n',
#  'abducent\tseparador\n',
#  'abducentes\tabducentes\n',
#  'abducing\tAbductor\n',
#  'abducing\tseparación\n',
#  'abduct\tsecuestrar, raptar\n',
#  'abducted\tsecuestrado, raptado\n',
#  'abducted\tSeparado de la línea media del cuerpo.\n',
#  'abducting\tsecuestrando, raptando\n',
#  'abducting\tseparando, alejando de la línea media.\n',
#  'abduction\tAbducción, secuestro, rapto\n',
#  'abduction\tsecuestro, rapto\n',
#  'abductions\tsecuestros, raptos\n',
#  'abductor\tAbductor\n',
#  'abductor\tsecuestrador\n',
#  'abductors\tAbductores\n',
#  'abductors\tsecuestradores\n',
#  'abducts\tsecuestra, rapta\n',
#  'abeam\tal traves\n',
#  'abeam\tDe través\n',
#  'abecedarian\tabecedario\n',
#  'abed\ten cama, acostado\n',
#  'aberrance\tequivocacion, extravio\n',
#  'aberrancy\taberracion\n',
#  'aberrancy\terror\n',
#  'aberrant\taberrante\n',
#  'aberrant\tanomalo, irregular, errado\n',
#  'aberrantly\taberrantemente\n',
#  'aberrate\taberrar\n',
#  'aberrate\tdesviar\n',
#  'aberrated\taberrado\n',
#  'aberrated\tdesviado\n',
#  'aberration\taberracion\n',
#  'aberration\tdesviacion\n',
#  'aberrational\taberrante; desviado\n',
#  'aberrations\taberraciones\n',
#  'aberrations\tdesvios\n',
#  'abet\tanimar, colaborar\n',
#  'abet\tayudar\n',
#  'abet\tIncitar, inducir, To aid and abet, ser cómplice de.\n',
#  'abet\tinstigar, incitar, inducir\n',
#  'abetment\tcolaboracion\n',
#  'abetment\tComplicidad.\n',
#  'abetment\tinstigacin, apoyo\n',
#  'abetment\tinstigación, apoyo\n',
#  'abets\tapoya, colabora\n',
#  'abets\tayuda\n',
#  'abets\tencubre\n',
#  'abetted\tApoyado, instigado, incitado, colaborado\n',
#  'abetted\tapoyo, colaboro\n',
#  'abetted\tayudo\n',
#  'abetter\tinstigador, complice\n',
#  'abetting\tinstigando, incitando\n',
#  'abettor\tinstigador\n',
#  'abeyance\tin~ en desuso\n',
#  'abeyant\ten suspenso\n',
#  'abhor\tdetestar\n',
#  'abhor\todiar\n',
#  'abhor\taborrecer, abominar \n',
#  'abhorred\todiado\n',
#  'abhorred\taborrecido\n',
#  'abhorrence\todio\n',
#  'abhorrent\todioso\n',
#  'abhorrently\ten forma aborreciente, odiante\n',
#  'abhorrer\tla persona que odia\n',
#  'abhorring\taborreciente\n',
#  'abhors\todia\n',
#  'abidance\ttolerancia, conformismo\n',
#  'abide\trespetar\n',
#  'abide\ttolerar,aguantar\n',
#  'abide\tquedar\n',
#  'abided\tmoro\n',
#  'abider\tmorador\n',
#  'abides\tmora\n',
#  'abiding\tpermanente, perdurable\n',
#  'abidingly\tpermanentemente\n',
#  'abilities\thabilidades, capacidades\n',
#  'abilities\ttalentos\n',
#  'ability\thabilidad, capacidad\n',
#  'ability\ttalento\n',
#  'abiogenesis\tabiogenesis\n',
#  'abiogenetic\tabiogenético\n',
#  'abiogenetical\tabiogenético\n',
#  'abiogenetically\tabiogenéticamente\n',
#  'abiological\tabiológico\n',
#  'abiologically\tabológicamente\n',
#  'abiotic\tabiotico\n',
#  'abiotically\tabioticamente\n',
#  'abject\tabyecto\n',
#  'abject\tmiserable \n',
#  'abjection\tabyección\n',
#  'abjections\tabyecciones\n',
#  'abjectly\tabyectamente\n',
#  'abjectness\tabyeccion\n',
#  'abjuration\tabjuración\n',
#  'abjure\trenunciar\n',
#  'abjured\tabjurado\n',
#  'abjurer\tabjurar\n',
#  'abjures\tabjura\n',
#  'abjuring\tabjurando; abjuracion\n',
#  'ablate\textirpar\n',
#  'ablated\textirpado\n',
#  'ablating\textirpando\n',
#  'ablation\textirpación\n',
#  'ablation\tablacion\n',
#  'ablative\tablativo\n',
#  'ablaut\tquesontes\n',
#  'ablaze\tardiendo\n',
#  'ablaze\ten llamas\n',
#  'ablaze\ten llamas\n',
#  'ablaze\tardiente\n',
#  'able\tcapaz\n',
#  'able\thábil \n',
#  'abler\tmas capaz\n',
#  'abler\t más capazhábil\n',
#  'ablest\tmás capaz\n',
#  'ablest\t el más capazhábil\n',
#  'abloom\ten flor\n',
#  'ablution\tablución\n',
#  'ablutionary\tablucionario\n',
#  'ablutions\tabluciones\n',
#  'ably\thabilmente\n',
#  'ably\thábilmente\n',
#  'abnegate\tabnegar?\n',
#  'abnegate\tsacrificarse\n',
#  'abnegates\tabniega\n',
#  'abnegation\tabnegacion\n',
#  'abnegation\tabnegación \n',
#  'abnegator\tabnegador\n',
#  'abnormal\tanormal\n',
#  'abnormalities\tanormalidades\n',
#  'abnormality\tanormalmente\n',
#  'abnormality\tanormalidad\n',
#  'abnormality\tanormalidad\n',
#  'abnormalize\tanormalizar\n',
#  'abnormalizes\tanormaliza\n',
#  'abnormally\tanormalmente\n',
#  'aboard\ta bordo\n',
#  'aboard\ta bordo de\n',
#  'abode\tsin domicilio fijo\n',
#  'abodes\tdomicilios\n',
#  'aboil\tabolir\n',
#  'abolish\tabolir\n',
#  'abolish\tsuprimir, abolir\n',
#  'abolishable\tabolible\n',
#  'abolishable\tsuprimible\n',
#  'abolished\tabolido\n',
#  'abolisher\tabolicionista\n',
#  'abolishers\tabolicionistas\n',
#  'abolishes\tabole\n',
#  'abolishing\taboliendo\n',
#  'abolishment\tabolicion\n',
#  'abolition\tabolicion\n',
#  'abolition\tsupresión, abolición\n',
#  'abolitionary\tabolicionista\n',
#  'abolitionism\tabolicionismo\n',
#  'abolitionist\tabolicionista\n',
#  'abolitionists\tabolicionistas\n',
#  'abolitionize\tabolicionar\n',
#  'abomasal\tdel cuarto estómago\n',
#  'abominable\tabominable\n',
#  'abominably\tabominablemente\n',
#  'abominate\tabominar\n',
#  'abomination\tabominacion\n',
#  'abominations\tabominaciones\n',
#  'abominator\tabominador\n',
#  'abominators\tabominadores\n',
#  'aboral\taboral\n',
#  'aborally\tde manera aboral\n',
#  'aboriginal\taborigen\n',
#  'aboriginally\taboriginalmente\n',
#  'aborigine\taborigen,australino\n',
#  'aborigines\taborigenes\n',
#  'aborning\tnaciente\n',
#  'abort\tabortar\n',
#  'abort\taborto\n',
#  'aborted\tabortado\n',
#  'aborter\tabortante\n',
#  'abortifacient\tabortivo, que provoca aborto\n',
#  'aborting\tabortando\n',
#  'abortion\taborto\n',
#  'abortion\taborto \n',
#  'abortionist\tabortista\n',
#  'abortionists\tabortistas\n',
#  'abortions\tabortos\n',
#  'abortive\tabortivo\n',
#  'abortive\tmalogrado\n',
#  'abortively\tabortivamente\n',
#  'abortiveness\tcalidad de  abortivo, infructuoso\n',
#  'aborts\tabortos\n',
#  'abound\tabundar\n',
#  'abounded\tabundo\n',
#  'abounding\tabundando\n',
#  'abounds\tabunda\n',
#  'about\tacerca, sobre, a punto de\n',
#  'about\tmás o menos, aproximadamente\n',
#  'about\tpor todas partes\n',
#  'about\tde, sobre, acerca de; por\n',
#  'above\tarriba\n',
#  'above\tsobre\n',
#  'above\tencima, por encima, arriba\n',
#  'aboveboard\tlegitimo;honesto\n',
#  'aboveboard\tlegítimo\n',
#  'aboveground\tsobrenivel\n',
#  'abovementioned\tarriba citado,-a;susodicho,-a\n',
#  'abracadabra\tabracadabra\n',
#  'abradable\tabrasible, que se desgasta con fricción\n',
#  'abradant\tabrasivo\n',
#  'abrade\traer, raspar\n',
#  'abraded\traído, raspado\n',
#  'abrader\tque raspa, desgasta o limpia por fricción\n',
#  'abrades\traspar\n',
#  'abrading\traspando\n',
#  'abrasion\tabrasion\n',
#  'abrasion\traspon, raspadura\n',
#  'abrasions\tabrasiones\n',
#  'abrasive\tabrasivo\n',
#  'abrasive\tbrusco \n',
#  'abrasively\tabrasivamente\n',
#  'abrasively\tbruscamente \n',
#  'abrasiveness\tabrasividad\n',
#  'abrasives\tabrasuvis\n',
#  'abrasives\tabrasivos; bruscos \n',
#  'abreact\tliberar emociones verbalmente\n',
#  'abreaction\tabreaccion\n',
#  'abreast\tde frente: to walk four~, caminar cuatro de frente\n',
#  'abreast\tde frente: "to keep abreast of" : mantenerse al corriente de\n',
#  'abridge\tabreviar\n',
#  'abridged\tabreviado,-a; resumido,-a\n',
#  'abridgement\tcompendio\n',
#  'abridger\tcompendiador\n',
#  'abridges\tcompendia\n',
#  'abridging\tabreviando\n',
#  'abridgment\tabreviación\n',
#  'abroach\tespitado\n',
#  'abroad\ten el or la extranjaro\n',
#  'abroad\ten el extranjero \n',
#  'abrogate\tabrogar\n',
#  'abrogated\tabrrogado\n',
#  'abrogates\tabrroga\n',
#  'abrogating\tabrrogante\n',
#  'abrogation\tabrogacion\n',
#  'abrupt\tbrusco,-a;aspero;repentino,-a;subito;\n',
#  'abrupt\tbrusco \n',
#  'abruption\truptura, abrupcion\n',
#  'abruptly\tbruscamente; con aspereza; repentinamente\n',
#  'abruptly\trepentinamente \n',
#  'abruptness\tprecipitación, brusquedad\n',
#  'abscess\tabsceso\n',
#  'abscessed\tabscesado\n',
#  'abscesses\tabscesos\n',
#  'abscise\tabscisa\n',
#  'abscised\tcortado por abscision\n',
#  'abscissa\tabscisa\n',
#  'abscissae\tabcisa\n',
#  'abscissas\tabcisas\n',
#  'abscission\tabscision\n',
#  'abscond\tvi huir; fugarse\n',
#  'abscond\tescaparse\n',
#  'absconded\toculto\n',
#  'absconder\tfugitivo, prófugo, desertor\n',
#  'absconding\tfugandose\n',
#  'absconds\tocultarse, esconderse\n',
#  'absence\tausencia; falta;distraccion\n',
#  'absence\tausencia\n',
#  'absences\tausencias\n',
#  'absent\tausente\n',
#  'absent\tausente; \n',
#  'absented\tausente\n',
#  'absented\tausentado\n',
#  'absentee\tausente;absenista\n',
#  'absentee\tausente\n',
#  'absenteeism\tabsentismo\n',
#  'absentees\tausentes\n',
#  'absentia\tausencia\n',
#  'absenting\tausentando\n',
#  'absently\ten ausencia\n',
#  'absentminded\tdistraido,-a; despistado,-a\n',
#  'absentminded\tdistraído\n',
#  'absentmindedly\tdistraido\n',
#  'absentmindedly\tdistraidamente\n',
#  'absentmindedness\tolvidadizo\n',
#  'absents\tausentes\n',
#  'absinth\tajenjo\n',
#  'absinthe\tabsenta\n',
#  'absolute\tabsoluto,-a; completo,-a; puro,-a; incontrovertible; \n',
#  'absolute\tabsoluto\n',
#  'absolutely\tabsolutamente\n',
#  'absolutely\ttotalmente \n',
#  'absoluteness\tabsoluto\n',
#  'absolutes\tabsolutos\n',
#  'absolution\tabsolución\n',
#  'absolutism\tabsolutismo\n',
#  'absolutist\tabsolutista\n',
#  'absolutistic\tabsolutista\n',
#  'absolutization\tabsolutización\n',
#  'absolutize\tabsolutizar\n',
#  'absolutizes\tabsolutiza\n',
#  'absolve\tabsolver\n',
#  'absolved\tabsuelto\n',
#  'absolver\tabsolutor\n',
#  'absolves\tabsuelve\n',
#  'absolving\tabsolver\n',
#  'absorb\tabsorber\n',
#  'absorbability\tcapacidad de absorber\n',
#  'absorbable\tabsorbible\n',
#  'absorbance\tabsorvencia\n',
#  'absorbancy\tabsorbencia\n',
#  'absorbant\tabsorbente\n',
#  'absorbed\tabsorbido\n',
#  'absorbed\tabsorto\n',
#  'absorbency\tabsorbencia\n',
#  'absorbent\tabsorbente\n',
#  'absorber\tabsorber\n',
#  'absorbing\tabsorbente\n',
#  'absorbingly\tabsorbentemente\n',
#  'absorbs\tabsorbe\n',
#  'absorbtions\tabsorciones\n',
#  'absorptance\tabsortencia\n',
#  'absorption\tabsorcion\n',
#  'absorption\tabsorción\n',
#  'absorptive\tabsorbente\n',
#  'abstain\tabstener\n',
#  'abstain\tabstenerse de \n',
#  'abstain\tabsternerse\n',
#  'abstained\tabstinente\n',
#  'abstainer\tabstemio\n',
#  'abstaining\tabstinente\n',
#  'abstains\tabstiene\n',
#  'abstemious\tabstemio, -a\n',
#  'abstemiously\tde forma abstemia\n',
#  'abstention\tabstencion\n',
#  'abstentions\tabstenciones\n',
#  'abstentious\tabstencionista\n',
#  'abstinence\tabstinencia\n',
#  'abstinent\tabstinente\n',
#  'abstinently\tabstinentamente\n',
#  'abstract\tabstracto\n',
#  'abstract\tresumen\n',
#  'abstractable\tabstraíble\n',
#  'abstracted\tabstracto\n',
#  'abstractedly\tabstraidamente\n',
#  'abstractedness\tabstrasencia\n',
#  'abstracter\tabstractor\n',
#  'abstracting\tabstrayendo\n',
#  'abstraction\tabstracción\n',
#  'abstractionism\tabstraccionismo\n',
#  'abstractionists\tabstraccionistas\n',
#  'abstractions\tabstracciones\n',
#  'abstractly\tabstractamente\n',
#  'abstractness\tabstracto\n',
#  'abstractor\tabstractor\n',
#  'abstractors\tabstractores\n',
#  'abstracts\tabstractos\n',
#  'abstrict\tcercenar\n',
#  'abstriction\tabstriccion\n',
#  'abstruse\tabstruso\n',
#  'abstruseness\toscuridad\n',
#  'absurd\tabsurdo\n',
#  'absurdism\tabsurdismo\n',
#  'absurdities\tdisparates \n',
#  'absurdity\tabsurdo\n',
#  'absurdly\tabsurdamente\n',
#  'absurdness\tabsurdo\n',
#  'absurdum\tabsurdo\n',
#  'abundance\tabundancia\n',
#  'abundant\tabundante\n',
#  'abundantly\tabundantemente\n',
#  'abusable\tabusable\n',
#  'abuse\tabuso\n',
#  'abused\tmaltratado\n',
#  'abuser\tabusador\n',
#  'abusers\tabusadores\n',
#  'abuses\tabusa\n',
#  'abusing\tabusando\n',
#  'abusive\tabusivo\n',
#  'abusively\tabusivamente\n',
#  'abusiveness\tabusividad\n',
#  'abut\tterminar, confinar\n',
#  'abutilon\tabutilon,  geenero de las Malvaaceas\n',
#  'abutment\tlindero\n',
#  'abutments\testribos\n',
#  'abuts\tlindar\n',
#  'abysmal\tabismal\n',
#  'abysmally\tmalisimamente\n',
#  'abyss\tabismo\n',
#  'abyssal\tabisal\n',
#  'abysses\tabismos\n',
#  'acacia\tacacia\n',
#  'academe\tacademia\n',
#  'academia\tacademia\n',
#  'academic\tacademico\n',
#  'academical\tacadémico\n',
#  'academically\tacademicamente\n',
#  'academician\tacadémico\n',
#  'academicianship\tacademicismo\n',
#  'academicism\tacademicismo\n',
#  'academics\tacademicas\n',
#  'academies\tacademias\n',
#  'academism\tacademismo\n',
#  'academy\tacademia\n',
#  'acanthocephalan\tacantocéfalo\n',
#  'acanthopterygian\tacantopterigio\n',
#  'acanthus\tacanto\n',
#  'acanthuses\tacantos\n',
#  'acaulescent\tacaule, sin tallo\n',
#  'accede\taceder\n',
#  'acceded\taccedio\n',
#  'accedes\tconsentir en\n',
#  'acceding\taccediendo\n',
#  'accelerando\taccelerating\n',
#  'accelerate\tacelerar\n',
#  'accelerated\tacelerado\n',
#  'accelerates\tacelera\n',
#  'accelerating\tacelerando\n',
#  'acceleratingly\taceleradamente\n',
#  'acceleration\taceleracion\n',
#  'accelerations\taceleraciones\n',
#  'accelerative\tacelerativo\n',
#  'accelerator\tacelerador\n',
#  'accelerators\taceleradores\n',
#  'accelerometer\tacelerímetro\n',
#  'accelerometers\tacelerímetros\n',
#  'accent\taccento\n',
#  'accent\tel acento\n',
#  'accented\tacentuado\n',
#  'accenting\tacentuando\n',
#  'accentless\tsin acento\n',
#  'accents\taccentos\n',
#  'accentuate\tacentuar\n',
#  'accentuated\tacentuado\n',
#  'accentuates\tacentuar\n',
#  'accentuating\tacentuando\n',
#  'accentuation\tacentuacion\n',
#  'accept\taceptar\n',
#  'acceptability\taceptacion\n',
#  'acceptable\taceptable\n',
#  'acceptableness\taceptabilidad\n',
#  'acceptably\taceptable\n',
#  'acceptance\taceptación\n',
#  'acceptances\taceptaciones\n',
#  'acceptation\taceptacion\n',
#  'accepted\taceptado\n',
#  'acceptedly\taceptadamente\n',
#  'accepter\taceptor\n',
#  'accepting\taceptando\n',
#  'acceptingly\tcon aceptación\n',
#  'acceptor\taceptador\n',
#  'acceptors\taceptadores \n',
#  'accepts\taceptar\n',
#  'access\tacceso\n',
#  'accessary\taccesorio\n',
#  'accessed\taccedido\n',
#  'accesses\taccesos\n',
#  'accessibility\taccesibilidad\n',
#  'accessibility\tacesible\n',
#  'accessible\taccesible\n',
#  'accessibleness\taccesibilidad\n',
#  'accessibly\taccesiblemente\n',
#  'accessing\taccediendo\n',
#  'accession\tacceso\n',
#  'accessions\taccesos\n',
#  'accessorial\taccesorio\n',
#  'accessories\taccesorios\n',
#  'accessors\taccesores\n',
#  'accessory\taccesorio\n',
#  'accidence\taccidente\n',
#  'accident\tel accidente\n',
#  'accident\tun acidente\n',
#  'accident\t choque\n',
#  'accidental\taccidental\n',
#  'accidentalism\taccidentalismo\n',
#  'accidentalist\taacidentalista\n',
#  'accidentally\taccidentalmente\n',
#  'accidentally\tpor accidente\n',
#  'accidentalness\taccidentalmente\n',
#  'accidently\taccidentalmente\n',
#  'accidents\taccidentes\n',
#  'acclaim\taclamar\n',
#  'acclaim\taplaudir\n',
#  'acclaimed\taclamado\n',
#  'acclaimed\taplaudido\n',
#  'acclaims\taclamar\n',
#  'acclamation\taclamacion\n',
#  'acclimate\taclimar\n',
#  'acclimated\taclimatado\n',
#  'acclimates\taclimatar\n',
#  'acclimating\taclimatando\n',
#  'acclimation\taclimatacion\n',
#  'acclimatizable\taclimatable\n',
#  'acclimatization\taclimatacion\n',
#  'acclimatize\taclimatizado\n',
#  'acclimatize\tclimatizar\n',
#  'acclimatized\taclimatizado\n',
#  'acclimatized\tclimatizado\n',
#  'acclimatizer\tclimatizador\n',
#  'acclimatizers\tclimatizadores\n',
#  'acclimatizes\taclimatiza\n',
#  'acclivity\tcuesta, subida, pendiente\n',
#  'accolade\tespaldarazo\n',
#  'accolades\tacoladas\n',
#  'accommodate\tacomodar\n',
#  'accommodated\tacomodado\n',
#  'accommodated\talojado\n',
#  'accommodates\thospedar\n',
#  'accommodating\talojando\n',
#  'accommodatingly\tacomodadamente\n',
#  'accommodation\taccomadacion\n',
#  'accommodation\talojamiento\n',
#  'accommodations\talojamientos\n',
#  'accommodator\tacomodador\n',
#  'accompanied\tacompanado\n',
#  'accompanies\tacompaña\n',
#  'accompaniment\tacompan~amiento\n',
#  'accompaniments\tacompan~amientos\n',
#  'accompanist\tacompanista\n',
#  'accompanists\tacompanistas\n',
#  'accompany\tacompan~ar\n',
#  'accompanying\tacompan~ando\n',
#  'accompanyist\tacompan~ante\n',
#  'accompanyists\tacompan~antes\n',
#  'accomplice\tcómplice\n',
#  'accomplices\tcomplices\n',
#  'accomplish\tcumplido\n',
#  'accomplishable\tterminable\n',
#  'accomplished\tterminado\n',
#  'accomplisher\tterminador\n',
#  'accomplishers\tterminadores\n',
#  'accomplishes\ttermina  termino\n',
#  'accomplishing\tcumpliendo\n',
#  'accomplishment\ttriunfo\n',
#  'accomplishments\ttriunfos\n',
#  'accord\tacordar\n',
#  'accord\tacuerdo\n',
#  'accordance\tconforme\n',
#  'accordances\tconcordancias\n',
#  'accordant\tconcordante\n',
#  'accorded\tacordado\n',
#  'according\tde acuerdo con\n',
#  'accordingly\tpor consiguiente; en consecuencia\n',
#  'accordion\tacordeon\n',
#  'accordionist\tacordeonista\n',
#  'accordionists\tacordeonistas\n',
#  'accordions\tacordeones\n',
#  'accords\tacuerdos\n',
#  'accost\tabordar\n',
#  'accosted\tacoso\n',
#  'accosts\tabordar\n',
#  'account\tcuenta\n',
#  'accountability\tresponsabilidad\n',
#  'accountable\tresponsable\n',
#  'accountancy\tcontabilidad\n',
#  'accountant\tcontable\n',
#  'accountant\tel contador\n',
#  'accountants\tcontables\n',
#  'accounted\tcontabilizo, rindio cuentas\n',
#  'accounting\tcontabilidad\n',
#  'accountings\tcontabilidades\n',
#  'accounts\tcuentas\n',
#  'accouter\tequipar\n',
#  'accouterment\tequipo\n',
#  'accouterments\tequipo\n',
#  'accredit\tacreditar\n',
#  'accreditation\tacreditacion\n',
#  'accreditations\tacreditaciones\n',
#  'accredited\tautorizado\n',
#  'accretion\taumento\n',
#  'accretions\taumentos\n',
#  'accrue\taumentarse\n',
#  'acculturate\taculturar\n',
#  'acculturated\taculturado\n',
#  'accumulable\tacumulable\n',
#  'accumulate\tacumular\n',
#  'accumulate\tacumular\n',
#  'accumulated\tacumulado\n',
#  'accumulates\tacumuladoa\n',
#  'accumulating\tacumulando\n',
#  'accumulation\tacumulación\n',
#  'accumulations\tacumulaciones\n',
#  'accumulative\tacumulativo\n',
#  'accumulatively\tacumulativamente\n',
#  'accumulator\tacumuladorra\n',
#  'accumulators\tacumuladores\n',
#  'accuracies\tprecisiones\n',
#  'accuracy\tacuracia\n',
#  'accuracy\tprecisión\n',
#  'accurate\tatinado, preciso\n',
#  'accurate\texacto, preciso\n',
#  'accurately\tprecisión\n',
#  'accursed\tmaldito\n',
#  'accusation\tacusacion\n',
#  'accusations\tacusaciones\n',
#  'accusative\tacusativova\n',
#  'accusatory\tacusatorioa\n',
#  'accuse\tacusar\n',
#  'accused\tacusadoda\n',
#  'accuser\tacusadorra\n',
#  'accuses\tacusas\n',
#  'accusing\tacusando\n',
#  'accusor\tacusadorra\n',
#  'accustom\tacostumbrar\n',
#  'accustomed\tacostumbrado\n',
#  'accustoming\tacostumbrando\n',
#  'ace\tas\n',
#  'acellular\tacelular\n',
#  'acephalous\tacefalo\n',
#  'acerbate\tacerbar\n',
#  'acerbity\tacerbidad, acritud\n',
#  'acetaldehyde\tacetaldehido\n',
#  'acetamide\tacetamida\n',
#  'acetaminophen\tacetaminofen\n',
#  'acetaminophen\tacetaminofen\n',
#  'acetate\tacetato\n',
#  'acetic\tacético\n',
#  'acetify\tacetificar\n',
#  'acetone\tacetona\n',
#  'acetyl\tacetilo\n',
#  'acetylene\tAcetileno\n',
#  'ache\tdoler\n',
#  'ache\tdolor\n',
#  'ached\tdolido\n',
#  'ached\tdolió\n',
#  'aches\tduele\n',
#  'achievable\tconseguible\n',
#  'achievable\tlograble\n',
#  'achieve\tconseguir\n',
#  'achieve\tlograr\n',
#  'achieved\tconseguido\n',
#  'achieved\tlogró\n',
#  'achievement\tlogro\n',
#  'achievements\tlogros\n',
#  'achiever\tpersona que logra sus metas\n',
#  'achievers\tpersonas que logran sus metas\n',
#  'achieves\tlogra\n',
#  'achieving\tconsiguiendo\n',
#  'achieving\tque logra\n',
#  'aching\tque duele\n',
#  'achingly\tdolorosamente\n',
#  'achromatic\tacromático\n',
#  'achromatically\tacromaticamente\n',
#  'achromaticity\tacromaticidad\n',
#  'achromatism\tacromatismo\n',
#  'acid\tacido\n',
#  'acid\tácido\n',
#  'acidic\tacido\n',
#  'acidification\tacidificación\n',
#  'acidifier\tque vuelve acído\n',
#  'acidify\tvolver acído\n',
#  'acidimeter\tMedidor de acidez\n',
#  'acidimeters\tMedidores de acidez\n',
#  'acidity\tacidez\n',
#  'acidness\tacidez\n',
#  'acids\tacidos\n',
#  'acidulant\tacidulante\n',
#  'acidulate\tAcidular\n',
#  'acidulation\tAcidulación\n',
#  'acinus\tacino\n',
#  'acknowledge\treconocer\n',
#  'acknowledgeable\treconocible\n',
#  'acknowledged\treconocido\n',
#  'acknowledgement\treconocimiento\n',
#  'acknowledgements\treconocimientos\n',
#  'acknowledger\tpersona que reconoce\n',
#  'acknowledging\treconociendo\n',
#  'acknowledgment\treconocimiento\n',
#  'acne\tacné\n',
#  'acolyte\tacolito\n',
#  'acolytes\tacolitos\n',
#  'acorn\tbellota\n',
#  'acorns\tbellotas\n',
#  'acoustic\tAcústica\n',
#  'acoustic\tacustico\n',
#  'acoustically\tAcústicamente\n',
#  'acoustics\tacústica\n',
#  'acquaint\tconocido\n',
#  'acquaintance\tconocidoda\n',
#  'acquaintances\tconocidosdas\n',
#  'acquire\tAdquirir\n',
#  'acquired\tAdquirido\n',
#  'acquirement\tAdquisición\n',
#  'acquires\tvt   adquirir\n',
#  'acquisition\tadquisición\n',
#  'acquisitions\tAdquisiciones\n',
#  'acre\tacre\n',
#  'acrobacy\tAcrobacia\n',
#  'acrobat\tacróbata\n',
#  'acrobatic\tacrobático\n',
#  'acrobatically\tacrobaticamente\n',
#  'acrobatics\tacrobacias\n',
#  'acrobats\tacróbatas\n',
#  'acronym\tAcrónimo\n',
#  'acronymically\tacronímicamente\n',
#  'acronyms\tacrónimos\n',
#  'acropetal\tacropetalico\n',
#  'acropetally\tacropetalicamente\n',
#  'acrophobic\tAcrofobia\n',
#  'acropolis\tAcrópolis\n',
#  'across\ta través\n',
#  'acrostic\tAcróstico\n',
#  'acrylic\tAcrílico.\n',
#  'act\tn- acto, vi  expresar impulsos reprinudos en conducta sin inhibiciones\n',
#  'action\taccion\n',
#  'actions\tacciones\n',
#  'activate\tactivar\n',
#  'activated\tActivado\n',
#  'activates\tActiva\n',
#  'activation\tActivación\n',
#  'activations\tActivaciones\n',
#  'activator\tActivador\n',
#  'activators\tActivadores\n',
#  'active\tactivo\n',
#  'actively\tactivamente\n',
#  'activeness\tCualidad de ser activo.\n',
#  'activism\tActivismo\n',
#  'activist\tActivista\n',
#  'activists\tActivistas\n',
#  'activities\tlas actividades\n',
#  'activity\tActividad\n',
#  'actor\tun actor\n',
#  'actors\tlos actores\n',
#  'actress\tuna actriz\n',
#  'actresses\tActrices\n',
#  'actual\tactual\n',
#  'actualization\tActualización.\n',
#  'actualizations\tActualizaciones\n',
#  'actualize\tActualizar\n',
#  'actualized\tActualizado\n',
#  'actualizes\tActualiza\n',
#  'acuity\tn agudeza; visual _____ agudeza visual\n',
#  'aculeate\taculeado\n',
#  'acumen\tacumen\n',
#  'acuminate\tacuminado\n',
#  'acumination\tacuminacion\n',
#  'acupuncture\tAcupuntura.\n',
#  'acute\tAguda,agudo.\n',
#  'acutely\tAgudamente.\n',
#  'acuteness\tAgudeza\n',
#  'acyclic\tAcíclico.\n',
#  'acyclically\tAcíclicamente\n',
#  'adapt\tadaptar\n',
#  'adapt\tadaptar\n',
#  'adaptability\tadaptabilidad\n',
#  'adaptable\tadaptable\n',
#  'adaptation\tadaptacion\n',
#  'adaptational\tadaptacional\n',
#  'adaptations\tadaptaciones\n',
#  'adapted\tadaptado\n',
#  'adaption\tn - adaptacion \n',
#  'adaptive\tadaptativo\n',
#  'adaptively\tadaptativamente\n',
#  'adaptivity\tadaptabilidad\n',
#  'adaxial\tadaxial\n',
#  'add\tmas\n',
#  'add\tagregar;  sumar\n',
#  'addenda\tadendas\n',
#  'addendum\tadenda\n',
#  'addict\tadicto\n',
#  'addicted\t enviciarse volverse adicto\n',
#  'addiction\tAdicción.\n',
#  'addictions\tAdicciones.\n',
#  'addictive\tadictivo\n',
#  'addictive\tque crea habito\n',
#  'addicts\tadictos\n',
#  'addition\tadicion\n',
#  'additive\tadictivo, que crea habito (accent over  a  in habito\n',
#  'additive\taditivo )adj & noun)\n',
#  'additives\taditivos\n',
#  'address\tDirección\n',
#  'address\tdomicilio\n',
#  'addressed\tDirigido\n',
#  'addressee\tDestinatario\n',
#  'addressees\tDestinatarios\n',
#  'addresser\tRemitente\n',
#  'addressers\tRemitentes\n',
#  'addresses\tDirecciones\n',
#  'adductor\tAbductor\n',
#  'adenine\tadenina\n',
#  'adenoid\tAdenoide\n',
#  'adenoidal\tAdenoidal\n',
#  'adenoma\tAdenoma\n',
#  'adenomatous\tAdenomatoso\n',
#  'adenosine\tadenosina\n',
#  'adept\tAdepto\n',
#  'adequate\tadj - adecuado, suficiente\n',
#  'adhesion\tn - adherencia\n',
#  'adhesions\tn - adherencias\n',
#  'adhesive\tadj - adhesivo; ______ tape - tela or cinta adhesiva\n',
#  'adiabatic\tadiabatica \n',
#  'adios\tAdiós\n',
#  'adipose\tAdiposo\n',
#  'adiposity\tAdiposidad\n',
#  'adjacent\tAdyacente\n',
#  'adjective\tel adjetivo\n',
#  'adjectives\tAdjetivos.\n',
#  'adjust\tvt - ajustar, modificar\n',
#  'adjustable\tadj - ajustable\n',
#  'adjustment\tn -  ajuste -m; correccion -f  \n',
#  'adjuvant\tadj - adyuvante; coadyuvante\n',
#  'administration\tn  -  administracion -f  \n',
#  'administrators\tadministradores\n',
#  'admire\tadmirar\n',
#  'admission\tn - ; ingreso\n',
#  'admit\tvt -  internar, ingressar \n',
#  'admitted\tvt  internarse, ingresarse; She was admitted yesterday - Fue internada ayar; You need to be admitted - ud. necesita ser internado.\n',
#  'adobe\tadobe\n',
#  'adolescence\tn  - adolescencia\n',
#  'adolescent\tadj & n  -  adolescente\n',
#  'adopt\tvt  - adoptar\n',
#  'adoption\tadopcion\n',
#  'adoptions\tn  - adopciones -f \n',
#  'adoptive\tadj  - adoptivo\n',
#  'adrenalin\tn  - adrenalina\n',
#  'adsorbent\tadj  - adsorbente\n',
#  'adult\tadj & n  - adulto -ta \n',
#  'advance\tavance\n',
#  'advantage\tla ventaja\n',
#  'adverb\tel adverbio\n',
#  'advertisement\tel anuncio\n',
#  'advice\tel consejo\n',
#  'aerobic\tadj  - aerobico \n',
#  'aerobics\tn pl - aerobicos \n',
#  'aerosol\taerosol  -m\n',
#  'aerosolized\tadj  - en aerosol\n',
#  'affair\tasunto\n',
#  'affairs\tasuntos\n',
#  'affect\tn  -  afecto; vt afectar\n',
#  'affection\tn afecto, carino \n',
#  'affectionate\tcarinoso\n',
#  'affinities\tn pl  - affinidades  -f\n',
#  'affinity\tn  - affinidad  -f\n',
#  'affliction\tmal. achaque\n',
#  'aficionada\taficionada  -f\n',
#  'aficionado\taficionada  -m\n',
#  'afraid\tto be afraid - tener miedo\n',
#  'afterbirth\t\n',
#  'afternoon\tla tarde\n',
#  'aftertaste\tsabor  -m\n',
#  'again\totra vez\n',
#  'age\tedad -f;   middle age - edad madura or mediana; old age - vejez -f\n',
#  ...]

# %% [markdown]
# **Exercise**. Load the first translation of each word into a dictionary
# Take into account that:
# - Comment lines start with '#' and should be ignored
# - The English term is separated from the translation by a tab (\t)
# - A word can have multiple translations separated by commas: Select the first one
# - A word can be defined on multiple lines; choose the first one

# %%
translate = {}
for l in lines:
    if l[0] != "#" and l != "":
        l = l[:-1] # remove the \n in the end
        term_eng, all_spa = l.split('\t')
        terms_spa = all_spa.split(',')
        term_spa = terms_spa[0]
        if term_eng not in translate:
            translate[term_eng.lower()] = term_spa.lower()

# %%
translate
# Out:
# {'a': 'un',
#  'aardvark': 'cerdo hormiguero',
#  'aardvarks': 'cerdos hormigueros',
#  'ab': 'prefijo que indica separacion',
#  'aback': 'hacia atras',
#  'abacterial': 'abacteriano',
#  'abacus': 'abaco',
#  'abacuses': 'abacos',
#  'abaft': 'a popa ',
#  'abalone': 'abulon',
#  'abalones': 'abulones',
#  'abandon': 'abandonar',
#  'abandoned': 'abandonado',
#  'abandonee': 'abandonado',
#  'abandoner': 'abandonador',
#  'abandoning': 'abandonando',
#  'abandonment': 'abandono',
#  'abandonments': 'abandonos',
#  'abandons': 'abandona',
#  'abase': 'abatir',
#  'abased': 'degradado',
#  'abasement': 'envilecimiento',
#  'abasements': 'humillaciones',
#  'abaser': 'humillador',
#  'abases': 'degrada; humilla',
#  'abash': 'avergonzar',
#  'abashed': 'avergonzado',
#  'abashes': 'avergu.enza; pone en situacion embarazosa',
#  'abashing': 'vergonzante',
#  'abashment': 'vergüenza.',
#  'abasing': 'humillante',
#  'abate': 'amainar',
#  'abated': 'amainado',
#  'abatement': 'abolición',
#  'abatements': 'rebajas',
#  'abater': 'rebajador',
#  'abates': 'satélites',
#  'abating': ' superando una marca; disminuyendo; situacion depresiva',
#  'abatis': 'barricada con alambre de púas',
#  'abatises': 'barricads',
#  'abattoir': 'degolladero',
#  'abaxial': 'abacial',
#  'abbacy': 'abadía',
#  'abbas': 'abba= padre',
#  'abbe': 'abate',
#  'abberations': 'aberración',
#  'abbey': 'abadia',
#  'abbeys': 'abadías',
#  'abbot': 'abad',
#  'abbots': 'abades',
#  'abbreviate': 'abreviar',
#  'abbreviated': 'abreviado',
#  'abbreviates': 'abrevia',
#  'abbreviating': 'abreviando',
#  'abbreviation': 'abreviacion',
#  'abbreviations': 'abreviaciones',
#  'abbreviator': 'abreviador',
#  'abc': 'abc',
#  'abdicable': 'abdicable',
#  'abdicate': 'abdicar',
#  'abdicated': 'abdicado ',
#  'abdication': 'abdicacion',
#  'abdicator': 'abdicador',
#  'abdomen': 'abdomen',
#  'abdomens': 'abdomenes',
#  'abdominal': 'abdominal',
#  'abdominally': 'abdominalmente',
#  'abduce': 'abducir',
#  'abduced': 'abducido',
#  'abducens': 'músculo abductor',
#  'abducent': 'abductor',
#  'abducentes': 'abducentes',
#  'abducing': 'abductor',
#  'abduct': 'secuestrar',
#  'abducted': 'secuestrado',
#  'abducting': 'secuestrando',
#  'abduction': 'abducción',
#  'abductions': 'secuestros',
#  'abductor': 'abductor',
#  'abductors': 'abductores',
#  'abducts': 'secuestra',
#  'abeam': 'al traves',
#  'abecedarian': 'abecedario',
#  'abed': 'en cama',
#  'aberrance': 'equivocacion',
#  'aberrancy': 'aberracion',
#  'aberrant': 'aberrante',
#  'aberrantly': 'aberrantemente',
#  'aberrate': 'aberrar',
#  'aberrated': 'aberrado',
#  'aberration': 'aberracion',
#  'aberrational': 'aberrante; desviado',
#  'aberrations': 'aberraciones',
#  'abet': 'animar',
#  'abetment': 'colaboracion',
#  'abets': 'apoya',
#  'abetted': 'apoyado',
#  'abetter': 'instigador',
#  'abetting': 'instigando',
#  'abettor': 'instigador',
#  'abeyance': 'in~ en desuso',
#  'abeyant': 'en suspenso',
#  'abhor': 'detestar',
#  'abhorred': 'odiado',
#  'abhorrence': 'odio',
#  'abhorrent': 'odioso',
#  'abhorrently': 'en forma aborreciente',
#  'abhorrer': 'la persona que odia',
#  'abhorring': 'aborreciente',
#  'abhors': 'odia',
#  'abidance': 'tolerancia',
#  'abide': 'respetar',
#  'abided': 'moro',
#  'abider': 'morador',
#  'abides': 'mora',
#  'abiding': 'permanente',
#  'abidingly': 'permanentemente',
#  'abilities': 'habilidades',
#  'ability': 'habilidad',
#  'abiogenesis': 'abiogenesis',
#  'abiogenetic': 'abiogenético',
#  'abiogenetical': 'abiogenético',
#  'abiogenetically': 'abiogenéticamente',
#  'abiological': 'abiológico',
#  'abiologically': 'abológicamente',
#  'abiotic': 'abiotico',
#  'abiotically': 'abioticamente',
#  'abject': 'abyecto',
#  'abjection': 'abyección',
#  'abjections': 'abyecciones',
#  'abjectly': 'abyectamente',
#  'abjectness': 'abyeccion',
#  'abjuration': 'abjuración',
#  'abjure': 'renunciar',
#  'abjured': 'abjurado',
#  'abjurer': 'abjurar',
#  'abjures': 'abjura',
#  'abjuring': 'abjurando; abjuracion',
#  'ablate': 'extirpar',
#  'ablated': 'extirpado',
#  'ablating': 'extirpando',
#  'ablation': 'extirpación',
#  'ablative': 'ablativo',
#  'ablaut': 'quesontes',
#  'ablaze': 'ardiendo',
#  'able': 'capaz',
#  'abler': 'mas capaz',
#  'ablest': 'más capaz',
#  'abloom': 'en flor',
#  'ablution': 'ablución',
#  'ablutionary': 'ablucionario',
#  'ablutions': 'abluciones',
#  'ably': 'habilmente',
#  'abnegate': 'abnegar?',
#  'abnegates': 'abniega',
#  'abnegation': 'abnegacion',
#  'abnegator': 'abnegador',
#  'abnormal': 'anormal',
#  'abnormalities': 'anormalidades',
#  'abnormality': 'anormalmente',
#  'abnormalize': 'anormalizar',
#  'abnormalizes': 'anormaliza',
#  'abnormally': 'anormalmente',
#  'aboard': 'a bordo',
#  'abode': 'sin domicilio fijo',
#  'abodes': 'domicilios',
#  'aboil': 'abolir',
#  'abolish': 'abolir',
#  'abolishable': 'abolible',
#  'abolished': 'abolido',
#  'abolisher': 'abolicionista',
#  'abolishers': 'abolicionistas',
#  'abolishes': 'abole',
#  'abolishing': 'aboliendo',
#  'abolishment': 'abolicion',
#  'abolition': 'abolicion',
#  'abolitionary': 'abolicionista',
#  'abolitionism': 'abolicionismo',
#  'abolitionist': 'abolicionista',
#  'abolitionists': 'abolicionistas',
#  'abolitionize': 'abolicionar',
#  'abomasal': 'del cuarto estómago',
#  'abominable': 'abominable',
#  'abominably': 'abominablemente',
#  'abominate': 'abominar',
#  'abomination': 'abominacion',
#  'abominations': 'abominaciones',
#  'abominator': 'abominador',
#  'abominators': 'abominadores',
#  'aboral': 'aboral',
#  'aborally': 'de manera aboral',
#  'aboriginal': 'aborigen',
#  'aboriginally': 'aboriginalmente',
#  'aborigine': 'aborigen',
#  'aborigines': 'aborigenes',
#  'aborning': 'naciente',
#  'abort': 'abortar',
#  'aborted': 'abortado',
#  'aborter': 'abortante',
#  'abortifacient': 'abortivo',
#  'aborting': 'abortando',
#  'abortion': 'aborto',
#  'abortionist': 'abortista',
#  'abortionists': 'abortistas',
#  'abortions': 'abortos',
#  'abortive': 'abortivo',
#  'abortively': 'abortivamente',
#  'abortiveness': 'calidad de  abortivo',
#  'aborts': 'abortos',
#  'abound': 'abundar',
#  'abounded': 'abundo',
#  'abounding': 'abundando',
#  'abounds': 'abunda',
#  'about': 'acerca',
#  'above': 'arriba',
#  'aboveboard': 'legitimo;honesto',
#  'aboveground': 'sobrenivel',
#  'abovementioned': 'arriba citado',
#  'abracadabra': 'abracadabra',
#  'abradable': 'abrasible',
#  'abradant': 'abrasivo',
#  'abrade': 'raer',
#  'abraded': 'raído',
#  'abrader': 'que raspa',
#  'abrades': 'raspar',
#  'abrading': 'raspando',
#  'abrasion': 'abrasion',
#  'abrasions': 'abrasiones',
#  'abrasive': 'abrasivo',
#  'abrasively': 'abrasivamente',
#  'abrasiveness': 'abrasividad',
#  'abrasives': 'abrasuvis',
#  'abreact': 'liberar emociones verbalmente',
#  'abreaction': 'abreaccion',
#  'abreast': 'de frente: to walk four~',
#  'abridge': 'abreviar',
#  'abridged': 'abreviado',
#  'abridgement': 'compendio',
#  'abridger': 'compendiador',
#  'abridges': 'compendia',
#  'abridging': 'abreviando',
#  'abridgment': 'abreviación',
#  'abroach': 'espitado',
#  'abroad': 'en el or la extranjaro',
#  'abrogate': 'abrogar',
#  'abrogated': 'abrrogado',
#  'abrogates': 'abrroga',
#  'abrogating': 'abrrogante',
#  'abrogation': 'abrogacion',
#  'abrupt': 'brusco',
#  'abruption': 'ruptura',
#  'abruptly': 'bruscamente; con aspereza; repentinamente',
#  'abruptness': 'precipitación',
#  'abscess': 'absceso',
#  'abscessed': 'abscesado',
#  'abscesses': 'abscesos',
#  'abscise': 'abscisa',
#  'abscised': 'cortado por abscision',
#  'abscissa': 'abscisa',
#  'abscissae': 'abcisa',
#  'abscissas': 'abcisas',
#  'abscission': 'abscision',
#  'abscond': 'vi huir; fugarse',
#  'absconded': 'oculto',
#  'absconder': 'fugitivo',
#  'absconding': 'fugandose',
#  'absconds': 'ocultarse',
#  'absence': 'ausencia; falta;distraccion',
#  'absences': 'ausencias',
#  'absent': 'ausente',
#  'absented': 'ausente',
#  'absentee': 'ausente;absenista',
#  'absenteeism': 'absentismo',
#  'absentees': 'ausentes',
#  'absentia': 'ausencia',
#  'absenting': 'ausentando',
#  'absently': 'en ausencia',
#  'absentminded': 'distraido',
#  'absentmindedly': 'distraido',
#  'absentmindedness': 'olvidadizo',
#  'absents': 'ausentes',
#  'absinth': 'ajenjo',
#  'absinthe': 'absenta',
#  'absolute': 'absoluto',
#  'absolutely': 'absolutamente',
#  'absoluteness': 'absoluto',
#  'absolutes': 'absolutos',
#  'absolution': 'absolución',
#  'absolutism': 'absolutismo',
#  'absolutist': 'absolutista',
#  'absolutistic': 'absolutista',
#  'absolutization': 'absolutización',
#  'absolutize': 'absolutizar',
#  'absolutizes': 'absolutiza',
#  'absolve': 'absolver',
#  'absolved': 'absuelto',
#  'absolver': 'absolutor',
#  'absolves': 'absuelve',
#  'absolving': 'absolver',
#  'absorb': 'absorber',
#  'absorbability': 'capacidad de absorber',
#  'absorbable': 'absorbible',
#  'absorbance': 'absorvencia',
#  'absorbancy': 'absorbencia',
#  'absorbant': 'absorbente',
#  'absorbed': 'absorbido',
#  'absorbency': 'absorbencia',
#  'absorbent': 'absorbente',
#  'absorber': 'absorber',
#  'absorbing': 'absorbente',
#  'absorbingly': 'absorbentemente',
#  'absorbs': 'absorbe',
#  'absorbtions': 'absorciones',
#  'absorptance': 'absortencia',
#  'absorption': 'absorcion',
#  'absorptive': 'absorbente',
#  'abstain': 'abstener',
#  'abstained': 'abstinente',
#  'abstainer': 'abstemio',
#  'abstaining': 'abstinente',
#  'abstains': 'abstiene',
#  'abstemious': 'abstemio',
#  'abstemiously': 'de forma abstemia',
#  'abstention': 'abstencion',
#  'abstentions': 'abstenciones',
#  'abstentious': 'abstencionista',
#  'abstinence': 'abstinencia',
#  'abstinent': 'abstinente',
#  'abstinently': 'abstinentamente',
#  'abstract': 'abstracto',
#  'abstractable': 'abstraíble',
#  'abstracted': 'abstracto',
#  'abstractedly': 'abstraidamente',
#  'abstractedness': 'abstrasencia',
#  'abstracter': 'abstractor',
#  'abstracting': 'abstrayendo',
#  'abstraction': 'abstracción',
#  'abstractionism': 'abstraccionismo',
#  'abstractionists': 'abstraccionistas',
#  'abstractions': 'abstracciones',
#  'abstractly': 'abstractamente',
#  'abstractness': 'abstracto',
#  'abstractor': 'abstractor',
#  'abstractors': 'abstractores',
#  'abstracts': 'abstractos',
#  'abstrict': 'cercenar',
#  'abstriction': 'abstriccion',
#  'abstruse': 'abstruso',
#  'abstruseness': 'oscuridad',
#  'absurd': 'absurdo',
#  'absurdism': 'absurdismo',
#  'absurdities': 'disparates ',
#  'absurdity': 'absurdo',
#  'absurdly': 'absurdamente',
#  'absurdness': 'absurdo',
#  'absurdum': 'absurdo',
#  'abundance': 'abundancia',
#  'abundant': 'abundante',
#  'abundantly': 'abundantemente',
#  'abusable': 'abusable',
#  'abuse': 'abuso',
#  'abused': 'maltratado',
#  'abuser': 'abusador',
#  'abusers': 'abusadores',
#  'abuses': 'abusa',
#  'abusing': 'abusando',
#  'abusive': 'abusivo',
#  'abusively': 'abusivamente',
#  'abusiveness': 'abusividad',
#  'abut': 'terminar',
#  'abutilon': 'abutilon',
#  'abutment': 'lindero',
#  'abutments': 'estribos',
#  'abuts': 'lindar',
#  'abysmal': 'abismal',
#  'abysmally': 'malisimamente',
#  'abyss': 'abismo',
#  'abyssal': 'abisal',
#  'abysses': 'abismos',
#  'acacia': 'acacia',
#  'academe': 'academia',
#  'academia': 'academia',
#  'academic': 'academico',
#  'academical': 'académico',
#  'academically': 'academicamente',
#  'academician': 'académico',
#  'academicianship': 'academicismo',
#  'academicism': 'academicismo',
#  'academics': 'academicas',
#  'academies': 'academias',
#  'academism': 'academismo',
#  'academy': 'academia',
#  'acanthocephalan': 'acantocéfalo',
#  'acanthopterygian': 'acantopterigio',
#  'acanthus': 'acanto',
#  'acanthuses': 'acantos',
#  'acaulescent': 'acaule',
#  'accede': 'aceder',
#  'acceded': 'accedio',
#  'accedes': 'consentir en',
#  'acceding': 'accediendo',
#  'accelerando': 'accelerating',
#  'accelerate': 'acelerar',
#  'accelerated': 'acelerado',
#  'accelerates': 'acelera',
#  'accelerating': 'acelerando',
#  'acceleratingly': 'aceleradamente',
#  'acceleration': 'aceleracion',
#  'accelerations': 'aceleraciones',
#  'accelerative': 'acelerativo',
#  'accelerator': 'acelerador',
#  'accelerators': 'aceleradores',
#  'accelerometer': 'acelerímetro',
#  'accelerometers': 'acelerímetros',
#  'accent': 'accento',
#  'accented': 'acentuado',
#  'accenting': 'acentuando',
#  'accentless': 'sin acento',
#  'accents': 'accentos',
#  'accentuate': 'acentuar',
#  'accentuated': 'acentuado',
#  'accentuates': 'acentuar',
#  'accentuating': 'acentuando',
#  'accentuation': 'acentuacion',
#  'accept': 'aceptar',
#  'acceptability': 'aceptacion',
#  'acceptable': 'aceptable',
#  'acceptableness': 'aceptabilidad',
#  'acceptably': 'aceptable',
#  'acceptance': 'aceptación',
#  'acceptances': 'aceptaciones',
#  'acceptation': 'aceptacion',
#  'accepted': 'aceptado',
#  'acceptedly': 'aceptadamente',
#  'accepter': 'aceptor',
#  'accepting': 'aceptando',
#  'acceptingly': 'con aceptación',
#  'acceptor': 'aceptador',
#  'acceptors': 'aceptadores ',
#  'accepts': 'aceptar',
#  'access': 'acceso',
#  'accessary': 'accesorio',
#  'accessed': 'accedido',
#  'accesses': 'accesos',
#  'accessibility': 'accesibilidad',
#  'accessible': 'accesible',
#  'accessibleness': 'accesibilidad',
#  'accessibly': 'accesiblemente',
#  'accessing': 'accediendo',
#  'accession': 'acceso',
#  'accessions': 'accesos',
#  'accessorial': 'accesorio',
#  'accessories': 'accesorios',
#  'accessors': 'accesores',
#  'accessory': 'accesorio',
#  'accidence': 'accidente',
#  'accident': 'el accidente',
#  'accidental': 'accidental',
#  'accidentalism': 'accidentalismo',
#  'accidentalist': 'aacidentalista',
#  'accidentally': 'accidentalmente',
#  'accidentalness': 'accidentalmente',
#  'accidently': 'accidentalmente',
#  'accidents': 'accidentes',
#  'acclaim': 'aclamar',
#  'acclaimed': 'aclamado',
#  'acclaims': 'aclamar',
#  'acclamation': 'aclamacion',
#  'acclimate': 'aclimar',
#  'acclimated': 'aclimatado',
#  'acclimates': 'aclimatar',
#  'acclimating': 'aclimatando',
#  'acclimation': 'aclimatacion',
#  'acclimatizable': 'aclimatable',
#  'acclimatization': 'aclimatacion',
#  'acclimatize': 'aclimatizado',
#  'acclimatized': 'aclimatizado',
#  'acclimatizer': 'climatizador',
#  'acclimatizers': 'climatizadores',
#  'acclimatizes': 'aclimatiza',
#  'acclivity': 'cuesta',
#  'accolade': 'espaldarazo',
#  'accolades': 'acoladas',
#  'accommodate': 'acomodar',
#  'accommodated': 'acomodado',
#  'accommodates': 'hospedar',
#  'accommodating': 'alojando',
#  'accommodatingly': 'acomodadamente',
#  'accommodation': 'accomadacion',
#  'accommodations': 'alojamientos',
#  'accommodator': 'acomodador',
#  'accompanied': 'acompanado',
#  'accompanies': 'acompaña',
#  'accompaniment': 'acompan~amiento',
#  'accompaniments': 'acompan~amientos',
#  'accompanist': 'acompanista',
#  'accompanists': 'acompanistas',
#  'accompany': 'acompan~ar',
#  'accompanying': 'acompan~ando',
#  'accompanyist': 'acompan~ante',
#  'accompanyists': 'acompan~antes',
#  'accomplice': 'cómplice',
#  'accomplices': 'complices',
#  'accomplish': 'cumplido',
#  'accomplishable': 'terminable',
#  'accomplished': 'terminado',
#  'accomplisher': 'terminador',
#  'accomplishers': 'terminadores',
#  'accomplishes': 'termina  termino',
#  'accomplishing': 'cumpliendo',
#  'accomplishment': 'triunfo',
#  'accomplishments': 'triunfos',
#  'accord': 'acordar',
#  'accordance': 'conforme',
#  'accordances': 'concordancias',
#  'accordant': 'concordante',
#  'accorded': 'acordado',
#  'according': 'de acuerdo con',
#  'accordingly': 'por consiguiente; en consecuencia',
#  'accordion': 'acordeon',
#  'accordionist': 'acordeonista',
#  'accordionists': 'acordeonistas',
#  'accordions': 'acordeones',
#  'accords': 'acuerdos',
#  'accost': 'abordar',
#  'accosted': 'acoso',
#  'accosts': 'abordar',
#  'account': 'cuenta',
#  'accountability': 'responsabilidad',
#  'accountable': 'responsable',
#  'accountancy': 'contabilidad',
#  'accountant': 'contable',
#  'accountants': 'contables',
#  'accounted': 'contabilizo',
#  'accounting': 'contabilidad',
#  'accountings': 'contabilidades',
#  'accounts': 'cuentas',
#  'accouter': 'equipar',
#  'accouterment': 'equipo',
#  'accouterments': 'equipo',
#  'accredit': 'acreditar',
#  'accreditation': 'acreditacion',
#  'accreditations': 'acreditaciones',
#  'accredited': 'autorizado',
#  'accretion': 'aumento',
#  'accretions': 'aumentos',
#  'accrue': 'aumentarse',
#  'acculturate': 'aculturar',
#  'acculturated': 'aculturado',
#  'accumulable': 'acumulable',
#  'accumulate': 'acumular',
#  'accumulated': 'acumulado',
#  'accumulates': 'acumuladoa',
#  'accumulating': 'acumulando',
#  'accumulation': 'acumulación',
#  'accumulations': 'acumulaciones',
#  'accumulative': 'acumulativo',
#  'accumulatively': 'acumulativamente',
#  'accumulator': 'acumuladorra',
#  'accumulators': 'acumuladores',
#  'accuracies': 'precisiones',
#  'accuracy': 'acuracia',
#  'accurate': 'atinado',
#  'accurately': 'precisión',
#  'accursed': 'maldito',
#  'accusation': 'acusacion',
#  'accusations': 'acusaciones',
#  'accusative': 'acusativova',
#  'accusatory': 'acusatorioa',
#  'accuse': 'acusar',
#  'accused': 'acusadoda',
#  'accuser': 'acusadorra',
#  'accuses': 'acusas',
#  'accusing': 'acusando',
#  'accusor': 'acusadorra',
#  'accustom': 'acostumbrar',
#  'accustomed': 'acostumbrado',
#  'accustoming': 'acostumbrando',
#  'ace': 'as',
#  'acellular': 'acelular',
#  'acephalous': 'acefalo',
#  'acerbate': 'acerbar',
#  'acerbity': 'acerbidad',
#  'acetaldehyde': 'acetaldehido',
#  'acetamide': 'acetamida',
#  'acetaminophen': 'acetaminofen',
#  'acetate': 'acetato',
#  'acetic': 'acético',
#  'acetify': 'acetificar',
#  'acetone': 'acetona',
#  'acetyl': 'acetilo',
#  'acetylene': 'acetileno',
#  'ache': 'doler',
#  'ached': 'dolido',
#  'aches': 'duele',
#  'achievable': 'conseguible',
#  'achieve': 'conseguir',
#  'achieved': 'conseguido',
#  'achievement': 'logro',
#  'achievements': 'logros',
#  'achiever': 'persona que logra sus metas',
#  'achievers': 'personas que logran sus metas',
#  'achieves': 'logra',
#  'achieving': 'consiguiendo',
#  'aching': 'que duele',
#  'achingly': 'dolorosamente',
#  'achromatic': 'acromático',
#  'achromatically': 'acromaticamente',
#  'achromaticity': 'acromaticidad',
#  'achromatism': 'acromatismo',
#  'acid': 'acido',
#  'acidic': 'acido',
#  'acidification': 'acidificación',
#  'acidifier': 'que vuelve acído',
#  'acidify': 'volver acído',
#  'acidimeter': 'medidor de acidez',
#  'acidimeters': 'medidores de acidez',
#  'acidity': 'acidez',
#  'acidness': 'acidez',
#  'acids': 'acidos',
#  'acidulant': 'acidulante',
#  'acidulate': 'acidular',
#  'acidulation': 'acidulación',
#  'acinus': 'acino',
#  'acknowledge': 'reconocer',
#  'acknowledgeable': 'reconocible',
#  'acknowledged': 'reconocido',
#  'acknowledgement': 'reconocimiento',
#  'acknowledgements': 'reconocimientos',
#  'acknowledger': 'persona que reconoce',
#  'acknowledging': 'reconociendo',
#  'acknowledgment': 'reconocimiento',
#  'acne': 'acné',
#  'acolyte': 'acolito',
#  'acolytes': 'acolitos',
#  'acorn': 'bellota',
#  'acorns': 'bellotas',
#  'acoustic': 'acústica',
#  'acoustically': 'acústicamente',
#  'acoustics': 'acústica',
#  'acquaint': 'conocido',
#  'acquaintance': 'conocidoda',
#  'acquaintances': 'conocidosdas',
#  'acquire': 'adquirir',
#  'acquired': 'adquirido',
#  'acquirement': 'adquisición',
#  'acquires': 'vt   adquirir',
#  'acquisition': 'adquisición',
#  'acquisitions': 'adquisiciones',
#  'acre': 'acre',
#  'acrobacy': 'acrobacia',
#  'acrobat': 'acróbata',
#  'acrobatic': 'acrobático',
#  'acrobatically': 'acrobaticamente',
#  'acrobatics': 'acrobacias',
#  'acrobats': 'acróbatas',
#  'acronym': 'acrónimo',
#  'acronymically': 'acronímicamente',
#  'acronyms': 'acrónimos',
#  'acropetal': 'acropetalico',
#  'acropetally': 'acropetalicamente',
#  'acrophobic': 'acrofobia',
#  'acropolis': 'acrópolis',
#  'across': 'a través',
#  'acrostic': 'acróstico',
#  'acrylic': 'acrílico.',
#  'act': 'n- acto',
#  'action': 'accion',
#  'actions': 'acciones',
#  'activate': 'activar',
#  'activated': 'activado',
#  'activates': 'activa',
#  'activation': 'activación',
#  'activations': 'activaciones',
#  'activator': 'activador',
#  'activators': 'activadores',
#  'active': 'activo',
#  'actively': 'activamente',
#  'activeness': 'cualidad de ser activo.',
#  'activism': 'activismo',
#  'activist': 'activista',
#  'activists': 'activistas',
#  'activities': 'las actividades',
#  'activity': 'actividad',
#  'actor': 'un actor',
#  'actors': 'los actores',
#  'actress': 'una actriz',
#  'actresses': 'actrices',
#  'actual': 'actual',
#  'actualization': 'actualización.',
#  'actualizations': 'actualizaciones',
#  'actualize': 'actualizar',
#  'actualized': 'actualizado',
#  'actualizes': 'actualiza',
#  'acuity': 'n agudeza; visual _____ agudeza visual',
#  'aculeate': 'aculeado',
#  'acumen': 'acumen',
#  'acuminate': 'acuminado',
#  'acumination': 'acuminacion',
#  'acupuncture': 'acupuntura.',
#  'acute': 'aguda',
#  'acutely': 'agudamente.',
#  'acuteness': 'agudeza',
#  'acyclic': 'acíclico.',
#  'acyclically': 'acíclicamente',
#  'adapt': 'adaptar',
#  'adaptability': 'adaptabilidad',
#  'adaptable': 'adaptable',
#  'adaptation': 'adaptacion',
#  'adaptational': 'adaptacional',
#  'adaptations': 'adaptaciones',
#  'adapted': 'adaptado',
#  'adaption': 'n - adaptacion ',
#  'adaptive': 'adaptativo',
#  'adaptively': 'adaptativamente',
#  'adaptivity': 'adaptabilidad',
#  'adaxial': 'adaxial',
#  'add': 'mas',
#  'addenda': 'adendas',
#  'addendum': 'adenda',
#  'addict': 'adicto',
#  'addicted': ' enviciarse volverse adicto',
#  'addiction': 'adicción.',
#  'addictions': 'adicciones.',
#  'addictive': 'adictivo',
#  'addicts': 'adictos',
#  'addition': 'adicion',
#  'additive': 'adictivo',
#  'additives': 'aditivos',
#  'address': 'dirección',
#  'addressed': 'dirigido',
#  'addressee': 'destinatario',
#  'addressees': 'destinatarios',
#  'addresser': 'remitente',
#  'addressers': 'remitentes',
#  'addresses': 'direcciones',
#  'adductor': 'abductor',
#  'adenine': 'adenina',
#  'adenoid': 'adenoide',
#  'adenoidal': 'adenoidal',
#  'adenoma': 'adenoma',
#  'adenomatous': 'adenomatoso',
#  'adenosine': 'adenosina',
#  'adept': 'adepto',
#  'adequate': 'adj - adecuado',
#  'adhesion': 'n - adherencia',
#  'adhesions': 'n - adherencias',
#  'adhesive': 'adj - adhesivo; ______ tape - tela or cinta adhesiva',
#  'adiabatic': 'adiabatica ',
#  'adios': 'adiós',
#  'adipose': 'adiposo',
#  'adiposity': 'adiposidad',
#  'adjacent': 'adyacente',
#  'adjective': 'el adjetivo',
#  'adjectives': 'adjetivos.',
#  'adjust': 'vt - ajustar',
#  'adjustable': 'adj - ajustable',
#  'adjustment': 'n -  ajuste -m; correccion -f  ',
#  'adjuvant': 'adj - adyuvante; coadyuvante',
#  'administration': 'n  -  administracion -f  ',
#  'administrators': 'administradores',
#  'admire': 'admirar',
#  'admission': 'n - ; ingreso',
#  'admit': 'vt -  internar',
#  'admitted': 'vt  internarse',
#  'adobe': 'adobe',
#  'adolescence': 'n  - adolescencia',
#  'adolescent': 'adj & n  -  adolescente',
#  'adopt': 'vt  - adoptar',
#  'adoption': 'adopcion',
#  'adoptions': 'n  - adopciones -f ',
#  'adoptive': 'adj  - adoptivo',
#  'adrenalin': 'n  - adrenalina',
#  'adsorbent': 'adj  - adsorbente',
#  'adult': 'adj & n  - adulto -ta ',
#  'advance': 'avance',
#  'advantage': 'la ventaja',
#  'adverb': 'el adverbio',
#  'advertisement': 'el anuncio',
#  'advice': 'el consejo',
#  'aerobic': 'adj  - aerobico ',
#  'aerobics': 'n pl - aerobicos ',
#  'aerosol': 'aerosol  -m',
#  'aerosolized': 'adj  - en aerosol',
#  'affair': 'asunto',
#  'affairs': 'asuntos',
#  'affect': 'n  -  afecto; vt afectar',
#  'affection': 'n afecto',
#  'affectionate': 'carinoso',
#  'affinities': 'n pl  - affinidades  -f',
#  'affinity': 'n  - affinidad  -f',
#  'affliction': 'mal. achaque',
#  'aficionada': 'aficionada  -f',
#  'aficionado': 'aficionada  -m',
#  'afraid': 'to be afraid - tener miedo',
#  'afterbirth': '',
#  'afternoon': 'la tarde',
#  'aftertaste': 'sabor  -m',
#  'again': 'otra vez',
#  'age': 'edad -f;   middle age - edad madura or mediana; old age - vejez -f',
#  'agencies': 'agencias',
#  'agency': 'agencia',
#  'agent': 'agente -m',
#  'aggravate': 'agravar',
#  'aggression': 'agresion',
#  'aggressions': 'agresiones',
#  'aggressive': 'agresivo',
#  'agile': 'agil',
#  'aging': 'envejecimiento',
#  'agitate': 'agitar; to become agitated agitarse',
#  'agitated': 'agitado',
#  'ago': 'hace; atras  hace dos semanas or dos semanas atras',
#  'agoraphobia': 'agorafobia',
#  'agree': 'acordar',
#  'agreement': 'el acuerdo',
#  'aid': 'la curita',
#  'aide': 'asistente -mf; ayudante -mf; auxiliar -mf',
#  'aids': 'la sida',
#  'ailment': 'mal -m; achaque -m; padecimiento',
#  'air': 'el aire',
#  'aircraft': 'el avión',
#  'airplanes': 'los aviones',
#  'airport': 'el aeropuerto',
#  'airsickness': 'mareo ',
#  'airway': ' via aerea',
#  'alarm': 'alarma',
#  'alarmed': 'alarmado',
#  'alarming': 'alarmante',
#  'alarmingly': 'alarmantemente',
#  'alcohol': 'alcohol',
#  'alcoholic': 'alcoholico',
#  'alcoholism': 'alcoholismo',
#  'ale': 'cerveza',
#  'algebra': 'algebra',
#  'algebraically': 'algebraicamente',
#  'algorithm': 'algoritmo',
#  'alibi': 'coartada',
#  'alien': 'extranjero',
#  'all': 'todo',
#  'allow': 'dejar',
#  'alloy': 'aleación',
#  'alloys': 'aleaciónes',
#  'allspice': 'malagueta',
#  'almond': 'la almendra',
#  'almost': 'casi',
#  'alphabet': 'el alfabeto',
#  'alphabetic': 'english',
#  'already': 'ya',
#  'also': 'tambien',
#  'although': 'aunque',
#  'altitude': 'la altitud',
#  'alto': 'long',
#  'aluminum': 'el aluminio',
#  'always': 'siempre',
#  'am': '2486',
#  'amalgamate': 'amalgamar',
#  'amalgamated': 'amalgamado',
#  'amass': 'amontonar',
#  'amassed': 'amontado',
#  'amateur': 'novicio',
#  'amaze': 'asombrar',
#  'amazed': 'asombrado',
#  'amazement': 'asombro',
#  'amazing': 'asombroso',
#  'ambassador': 'embajador',
#  'amber': 'ambre',
#  'ambulance': 'la ambulancia',
#  'amen': 'amen',
#  'amenities': 'amenidades',
#  'american': 'americano',
#  'amiable': 'amistable',
#  'amicably': 'amistablemente',
#  'amid': 'entre',
#  'amuse': 'divertir',
#  'amusing': 'divertido',
#  'ancient': 'antiguo',
#  'and': 'y',
#  'angry': 'enojado',
#  'animal': 'el animal',
#  'animalcule': 'animalculo',
#  'animate': 'animar',
#  'animated': 'animado',
#  'animation': 'animacion',
#  'anion': 'anion',
#  'aniseed': 'anis',
#  'anisotropic': 'anisotropous',
#  'ankle': 'el tobillo',
#  'ankles': 'los tobillos',
#  'annihilate': 'aniquilar',
#  'anniversaries': 'aniversarios',
#  'anniversary': 'aniversario',
#  'annotate': 'notar',
#  'annotated': 'notado',
#  'annotation': 'anotación',
#  'announce': 'anunciar',
#  'announced': 'anunciado',
#  'announcement': 'anuncio',
#  'announcements': 'anuncios',
#  'announcer': 'anunciador',
#  'announcers': 'anuciadors',
#  'announcing': 'estar anunciando',
#  'annoy': 'burlarse',
#  'annoys': 'se burla',
#  'annual': 'anual',
#  'answer': 'la respuesta',
#  'ant': 'hormiga',
#  'antacid': 'antiacido',
#  'antagonism': 'antagonismo',
#  'antagonist': 'antagonista',
#  'antagonistic': 'antagonico',
#  'antagonize': 'enemistarse con;',
#  'antarctic': 'antartico',
#  'ante': 'apuesta; ante...',
#  'anteater': 'oso hormiguero',
#  'antecedent': 'antecedente',
#  'antecedents': 'antecedentes',
#  'antechamber': 'antecamara; antesala',
#  'antedate': 'preceder; ser anterior a',
#  'antediluvian': 'antediluviano',
#  'antelope': 'antilope',
#  'antenatal': 'prenatal; antenatal',
#  'antenna': 'antena',
#  'antennae': 'antena',
#  'anterior': 'anterior a',
#  'anteroom': 'antesala; antecamara',
#  'anthem': 'motete; himno nacional',
#  'anther': 'antera',
#  'anthill': 'hormiguero',
#  'anthologies': 'antologias',
#  'anthologist': 'antologista',
#  'anthologize': 'hacer una antologia de',
#  'anthology': 'antologia',
#  'anthracite': 'antracita',
#  'anthrop': 'antrop',
#  'anthropocentric': 'antropocentrico',
#  'anthropoid': 'antropoide',
#  'anthropological': 'antropologico',
#  'anthropologist': 'antropologo',
#  'anthropology': 'antropologia',
#  'anthropomorphic': 'antropomorfico',
#  'anthropomorphism': 'antropomorfismo',
#  'anthropophagous': 'antropofago',
#  'anthropophagy': 'antropofagia',
#  'apartment': 'apartamento',
#  'apologize': 'disculparse',
#  'appetite': 'el apetito',
#  'appetizer': 'el aperitivo',
#  'applaud': 'aplaudir',
#  'applause': 'el aplauso',
#  'apple': 'apple',
#  'apples': 'las manzanas',
#  'applesauce': 'pure de manzana',
#  'applicable': 'aplicable',
#  'applicant': 'applicante',
#  'applicants': 'applicante',
#  'application': 'aplicacion',
#  'appointment': 'la cita',
#  'appointments': 'las citas',
#  'appreciate': 'apreciar',
#  'apricot': 'el chabacano',
#  'april': 'abril',
#  'apron': 'el delantal',
#  'aquarium': 'el acuarium',
#  'architect': 'el arquitecto',
#  'arena': 'corrida',
#  'argue': 'arguir',
#  'argument': 'el argumento',
#  'arm': 'el brazo',
#  'arms': 'los brazos',
#  'around': 'alrededor',
#  'arrange': 'arreglar',
#  'arrive': 'llegar',
#  'arrow': 'la flecha',
#  'art': 'arte',
#  'artefact': 'artefacto',
#  'arterial': 'pertinente al transito',
#  'arterialization': 'arterializacion',
#  'arterialize': 'arterializar',
#  'arteries': 'las arterias',
#  'arteriole': 'arteriola; pequena arteria',
#  'arterioles': 'las arteriolas; las pequen~a arterias',
#  'arteriosclerosis': 'arteriolosclerosis',
#  'artful': 'diestro; habilidos; astuto; artificioso',
#  'artfully': 'astutamente; ladinamente; artificiosamente; con artificio; con arte; diestramente',
#  'arthritic': 'artrítico',
#  'arthropod': 'artropodo',
#  'artichoke': 'la alcachofa',
#  'article': 'artículo',
#  'artificial': 'artificial',
#  'ashtray': 'el cenicero',
#  'ask': 'preguntar',
#  'asleep': 'dormido',
#  'aspirin': 'la aspirina',
#  'asterisk': 'el asterisco',
#  'at': 'a',
#  'ate': 'comi',
#  'athlete': 'el atleta',
#  'attainable': 'conseguilbe',
#  'attainableness': 'asequibilidad',
#  'attempt': 'intento',
#  ...}

# %% [markdown]
# **Exercise**. Using the previous dictionary, enter a phrase and translate it word by word. If a word has no translation, leave it as is surrounded by <>.

# %%
frase = "you will all pass"
words = frase.split(' ')
results = []
for w in words:
    trans = translate.get(w.lower(), None)
    if trans is None:
        trans = "<" + w + ">"
    results.append(trans)
result = " ".join(results)
print(result)
# Out:
# tu <will> todo pasar
